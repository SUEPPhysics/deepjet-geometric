# %%
import os, sys
import matplotlib.pyplot as plt
import h5py

# %%
dataDir = "/work/submit/lavezzo/offline_ML/raw/"
files = os.listdir(dataDir)

# %%
with h5py.File(dataDir+files[0],'r') as f:
    eta = f['Pfcand_cyl'][0][:,1]
    phi = f['Pfcand_cyl'][0][:,2]

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.subplots()
_ = ax.scatter(eta, phi)
_ = ax.set_xlabel(r'$\eta$')
_ = ax.set_ylabel(r'$\phi$')
