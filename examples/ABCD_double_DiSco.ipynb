# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import mplhep as hep
import hist
hep.style.use("CMS")
mpl.rcParams['figure.facecolor'] = 'white'

# %% [markdown]
# Read in the data

# %%
results = np.load("twoNets_l5/disco_results.npy")
save_dir = 'twoNets_l5/'

suep_cl1 = results[0][results[2] == 1]
suep_cl2 = results[1][results[2] == 1]
qcd_cl1 = results[0][results[2] == 0]
qcd_cl2 = results[1][results[2] == 0]

# %% [markdown]
# Make 2D histograms using the ABCD variables.

# %%
hist_abcd = (
     hist.new
    .Regular(100, 0, 1, name="cl1", label="Classifier Output 1")
    .Regular(100, 0, 1, name="cl2", label="Classifier Output 2")
    .Weight()
)

hist_abcd.fill(qcd_cl1, qcd_cl2)
# Out:
# Hist(
#   Regular(100, 0, 1, name='cl1', label='Classifier Output 1'),
#   Regular(100, 0, 1, name='cl2', label='Classifier Output 2'),
#   storage=Weight()) # Sum: WeightedSum(value=57435, variance=57435)

# %%
hist_abcd_suep = (
     hist.new
    .Regular(100, 0, 1, name="cl1", label="Classifier Output 1")
    .Regular(100, 0, 1, name="cl2", label="Classifier Output 2")
    .Weight()
)

hist_abcd_suep.fill(suep_cl1, suep_cl2)
# Out:
# Hist(
#   Regular(100, 0, 1, name='cl1', label='Classifier Output 1'),
#   Regular(100, 0, 1, name='cl2', label='Classifier Output 2'),
#   storage=Weight()) # Sum: WeightedSum(value=29934, variance=29934)

# %% [markdown]
# Make 1D projections out of the 2D histograms.

# %%
_ = hep.histplot(hist_abcd.project(0), label="QCD")
_ = hep.histplot(hist_abcd_suep.project(0), label="SUEP")
_ = plt.legend()
plt.yscale("log")
plt.savefig(save_dir+"1d_classifier_output_1.png")

# %%
_ = hep.histplot(hist_abcd.project(1), label="QCD")
_ = hep.histplot(hist_abcd_suep.project(1), label="SUEP")
_ = plt.legend()
plt.yscale("log")
plt.savefig(save_dir+"1d_classifier_output_2.png")

# %% [markdown]
# Check for closure in D region for QCD.

# %%
A = hist_abcd[0.1j:0.5j:sum,0.1j:0.5j:4j]
B = hist_abcd[0.1j:0.5j:sum,0.5j:1.0j:4j]
C = hist_abcd[0.5j:1.0j:sum,0.1j:0.5j:4j]
D = hist_abcd[0.5j:1.0j:sum,0.5j:1.0j:4j]
D_exp = B * C.sum().value / A.sum().value

fig = plt.figure(figsize=(10, 8))
main, sub = D.plot_ratio(D_exp,
                rp_num_label='D observed',
                rp_denom_label='D expected',
                rp_uncert_draw_type="bar")
fig.axes[0].set_yscale("log")
#fig.axes[0].set_xlim(0.5,1)
fig.axes[1].set_xlabel("Classifier Output")
fig.axes[1].set_ylim(0.3,1.8)
plt.savefig(save_dir+"ABCD_D_region.png")
# Out:
# /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/boost_histogram/_internal/view.py:172: RuntimeWarning: invalid value encountered in true_divide
#   ufunc(input_0["value"], input_1, out=result["value"], **kwargs)
# /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/boost_histogram/_internal/view.py:173: RuntimeWarning: invalid value encountered in true_divide
#   ufunc(
# /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/numpy/core/_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/numpy/core/_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 8>()
#       5 D_exp = B * C.sum().value / A.sum().value
#       7 fig = plt.figure(figsize=(10, 8))
# ----> 8 main, sub = D.plot_ratio(D_exp,
#       9                 rp_num_label='D observed',
#      10                 rp_denom_label='D expected',
#      11                 rp_uncert_draw_type="bar")
#      12 fig.axes[0].set_yscale("log")
#      13 #fig.axes[0].set_xlim(0.5,1)
#
# File /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/hist/basehist.py:471, in BaseHist.plot_ratio(self, other, ax_dict, **kwargs)
#     462 """
#     463 ``plot_ratio`` method for ``BaseHist`` object.
#     464
#     465 Return a tuple of artists following a structure of
#     466 ``(main_ax_artists, subplot_ax_artists)``
#     467 """
#     469 from hist import plot
# --> 471 return plot._plot_ratiolike(
#     472     self, other, ax_dict=ax_dict, view="ratio", **kwargs
#     473 )
#
# File /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/hist/plot.py:669, in _plot_ratiolike(self, other, likelihood, ax_dict, view, fit_fmt, **kwargs)
#     663     ratio_uncert = ratio_uncertainty(
#     664         num=hist_values,
#     665         denom=compare_values,
#     666         uncertainty_type=rp_kwargs["uncertainty_type"],
#     667     )
#     668     # ratio: plot the ratios using Matplotlib errorbar or bar
# --> 669     subplot_ax_artists = plot_ratio_array(
#     670         self, ratios, ratio_uncert, ax=subplot_ax, **rp_kwargs
#     671     )
#     673 elif view == "pull":
#     674     pulls: np.typing.NDArray[Any] = (
#     675         hist_values - compare_values
#     676     ) / hist_values_uncert
#
# File /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/hist/plot.py:465, in plot_ratio_array(__hist, ratio, ratio_uncert, ax, **kwargs)
#     458 valid_ratios = ratio[valid_ratios_idx]
#     459 extrema = np.array(
#     460     [
#     461         valid_ratios - ratio_uncert[0][valid_ratios_idx],
#     462         valid_ratios + ratio_uncert[1][valid_ratios_idx],
#     463     ]
#     464 )
# --> 465 max_delta = np.amax(np.abs(extrema - central_value))
#     466 ratio_extrema = np.abs(max_delta + central_value)
#     468 _alpha = 2.0
#
# File <__array_function__ internals>:5, in amax(*args, **kwargs)
#
# File /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2754, in amax(a, axis, out, keepdims, initial, where)
#    2638 @array_function_dispatch(_amax_dispatcher)
#    2639 def amax(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2640          where=np._NoValue):
#    2641     """
#    2642     Return the maximum of an array or maximum along an axis.
#    2643
#    (...)
#    2752     5
#    2753     """
# -> 2754     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2755                           keepdims=keepdims, initial=initial, where=where)
#
# File /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
# A = hist_abcd[0.05j:0.5j:sum,0.0j:0.05j:2j]
# B = hist_abcd[0.05j:0.5j:sum,0.05j:0.5j:2j]
# C = hist_abcd[0.05j:0.5j:sum,0.5j:1.0j:2j]
# D = hist_abcd[0.5j:1.0j:sum,0.0j:0.05j:2j]
# E = hist_abcd[0.5j:1.0j:sum,0.05j:0.5j:2j]
# F = hist_abcd[0.5j:1.0j:sum,0.5j:1.0j:2j]
A = hist_abcd[0.05j:0.5j:sum,0.0j:0.25j:2j]
B = hist_abcd[0.05j:0.5j:sum,0.25j:0.5j:2j]
C = hist_abcd[0.05j:0.5j:sum,0.5j:1.0j:2j]
D = hist_abcd[0.5j:1.0j:sum,0.0j:0.25j:2j]
E = hist_abcd[0.5j:1.0j:sum,0.25j:0.5j:2j]
F = hist_abcd[0.5j:1.0j:sum,0.5j:1.0j:2j]
F_exp = C * E.sum().value**2 * A.sum().value / (B.sum().value**2 * D.sum().value)

fig = plt.figure(figsize=(10, 8))
main, sub = F.plot_ratio(F_exp,
                rp_num_label='F observed',
                rp_denom_label='F expected',
                rp_uncert_draw_type="bar")
fig.axes[0].set_yscale("log")
#fig.axes[0].set_xlim(0.5,1)
fig.axes[1].set_xlabel("# Tracks")
fig.axes[1].set_ylim(0.4,1.6)
plt.savefig(save_dir+"ABCD_6regions.png")

# %% [markdown]
# Check for indendence of the two ABCD variables by making 1D histograms of different slices.

# %%
# parameters
save = True
slice_label = 'Classifier Output 1'            
slices = [[0.0j,0.2j],[0.2j,0.4j],[0.4j,0.6j],[0.6j,0.8j],[0.8j,1.0j]]

#  color map
cmap = plt.cm.rainbow(np.linspace(0, 1, len(slices)))

plt.clf()
for i in range(len(slices)):
    val_lo = slices[i][0]
    val_up = slices[i][1]
    
    h = hist_abcd[val_lo:val_up:sum,0.0j::2j]
            
    hep.histplot(h,
                 yerr=True, density=True, 
                 label=slice_label+" [{0},{1}]".format(val_lo.imag, val_up.imag))    

plt.legend()
plt.title("QCD")
#plt.xlim(0.0,1.0)
plt.ylim(1e-4,2)
plt.yscale('log')
plt.ylabel("Normalized Events")
plt.xlabel("# Tracks")
if save: plt.savefig(save_dir + "QCD_CL1_slices.png",  bbox_inches='tight')
# Out:
# /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/mplhep/utils.py:263: RuntimeWarning: divide by zero encountered in double_scalars
#   self.flat_scale(1 / np.sum(self.values))
# /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/mplhep/utils.py:243: RuntimeWarning: invalid value encountered in multiply
#   self.values *= scale
# /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/mplhep/utils.py:244: RuntimeWarning: invalid value encountered in multiply
#   self.yerr_lo *= scale
# /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/mplhep/utils.py:245: RuntimeWarning: invalid value encountered in multiply
#   self.yerr_hi *= scale
# /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/numpy/core/_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# /work/submit/lavezzo/miniforge3/envs/SUEP/lib/python3.9/site-packages/numpy/core/_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)

# %%
# parameters
save = True
slice_label = 'Classifier Output 2'            
slices = [[0.0j,0.2j],[0.2j,0.4j],[0.4j,0.6j],[0.6j,0.8j],[0.8j,1.0j]]

#  color map
cmap = plt.cm.rainbow(np.linspace(0, 1, len(slices)))

plt.clf()
for i in range(len(slices)):
    val_lo = slices[i][0]
    val_up = slices[i][1]
    
    h = hist_abcd[::2j, val_lo:val_up:sum]
            
    hep.histplot(h,
                 yerr=True, density=True, 
                 label=slice_label+" [{0},{1}]".format(val_lo.imag, val_up.imag))    

plt.legend()
plt.title("QCD")
plt.xlim(0.0,1.0)
plt.ylim(1e-4,2)
plt.yscale('log')
plt.ylabel("Normalized Events")
plt.xlabel("Classifier Output 1")
if save: plt.savefig(save_dir + "QCD_CL2_slices.png",  bbox_inches='tight')
